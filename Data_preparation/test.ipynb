# %%
import numpy as np
import xarray as xr

# %%
test = xr.open_dataarray("/Users/richard_zhang/Library/CloudStorage/OneDrive-Personal/A_Melbourne-Uni/A_Weather_for_21st_Century_RA_Internship/Local_Remote_Influences_on_Coastal_Rainfall/Data_preparation/OISST/northeast_sst.nc")

# %%
test
# Out:
# <xarray.DataArray 'sst' (time: 8035, lat: 122, lon: 122)>
# [119592940 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float64 -40.12 -39.88 -39.62 -39.38 ... -10.38 -10.12 -9.875
#   * lon      (lon) float64 139.9 140.1 140.4 140.6 ... 169.4 169.6 169.9 170.1
#   * time     (time) float64 1.0 2.0 3.0 4.0 ... 8.033e+03 8.034e+03 8.035e+03
