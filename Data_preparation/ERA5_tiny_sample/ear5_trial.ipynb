# %%
import numpy as np
import xarray as xa

# %%
accum_file_path = r'C:\Users\lv299\OneDrive\A_Melbourne-Uni\A_Weather_for_21st_Century_RA_Internship\Local_Remote_Influences_on_Coastal_Rainfall\Data_preparation\ERA5_tiny_sample\data_stream-oper_stepType-accum.nc'
accum = xa.open_dataset(accum_file_path)
accum
# Out:
# <xarray.Dataset>
# Dimensions:     (valid_time: 24, latitude: 81, longitude: 81)
# Coordinates:
#     number      int64 ...
#   * valid_time  (valid_time) datetime64[ns] 2025-02-03 ... 2025-02-03T23:00:00
#   * latitude    (latitude) float64 -10.0 -10.25 -10.5 ... -29.5 -29.75 -30.0
#   * longitude   (longitude) float64 140.0 140.2 140.5 ... 159.5 159.8 160.0
#     expver      (valid_time) object ...
# Data variables: (12/39)
#     tp          (valid_time, latitude, longitude) float32 ...
#     bld         (valid_time, latitude, longitude) float32 ...
#     cdir        (valid_time, latitude, longitude) float32 ...
#     cp          (valid_time, latitude, longitude) float32 ...
#     csf         (valid_time, latitude, longitude) float32 ...
#     uvb         (valid_time, latitude, longitude) float32 ...
#     ...          ...
#     tsr         (valid_time, latitude, longitude) float32 ...
#     tsrc        (valid_time, latitude, longitude) float32 ...
# ...

# %%
avg_file_path = r'C:\Users\lv299\OneDrive\A_Melbourne-Uni\A_Weather_for_21st_Century_RA_Internship\Local_Remote_Influences_on_Coastal_Rainfall\Data_preparation\ERA5_tiny_sample\data_stream-oper_stepType-avg.nc'
avg = xa.open_dataset(avg_file_path)
avg
# Out:
# <xarray.Dataset>
# Dimensions:         (valid_time: 24, latitude: 81, longitude: 81)
# Coordinates:
#     number          int64 ...
#   * valid_time      (valid_time) datetime64[ns] 2025-02-03 ... 2025-02-03T23:...
#   * latitude        (latitude) float64 -10.0 -10.25 -10.5 ... -29.5 -29.75 -30.0
#   * longitude       (longitude) float64 140.0 140.2 140.5 ... 159.5 159.8 160.0
#     expver          (valid_time) object ...
# Data variables: (12/39)
#     avg_ibld        (valid_time, latitude, longitude) float32 ...
#     avg_cpr         (valid_time, latitude, longitude) float32 ...
#     avg_csfr        (valid_time, latitude, longitude) float32 ...
#     avg_iegwss      (valid_time, latitude, longitude) float32 ...
#     avg_iews        (valid_time, latitude, longitude) float32 ...
#     avg_ie          (valid_time, latitude, longitude) float32 ...
#     ...              ...
#     avg_tnlwrf      (valid_time, latitude, longitude) float32 ...
# ...

# %%
np_avg = avg.to_array().values
np_ave
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39268\3475461527.py in <module>
#       1 np_avg = avg.to_array().values
# ----> 2 np_ave
#
# NameError: name 'np_ave' is not defined

# %%
! pip install selenium
# Out:
# ...
#      ---------------------------------------- 9.5/9.5 MB 20.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 492.9/492.9 kB 32.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.8/58.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 63.2/63.2 kB ? eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
# ...
