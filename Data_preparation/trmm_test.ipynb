# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import re
from datetime import datetime
import glob
import os

# %%
test = xr.open_dataset(r'C:\Users\lv299\OneDrive\A_Melbourne-Uni\A_Weather_for_21st_Century_RA_Internship\Local_Remote_Influences_on_Coastal_Rainfall\Data_preparation\precipitation_north_east_au.nc')

# %%
time_date = pd.date_range(start='1998-01-01', periods=8034, freq='D')
time_date
# Out:
# DatetimeIndex(['1998-01-01', '1998-01-02', '1998-01-03', '1998-01-04',
#                '1998-01-05', '1998-01-06', '1998-01-07', '1998-01-08',
#                '1998-01-09', '1998-01-10',
#                ...
#                '2019-12-21', '2019-12-22', '2019-12-23', '2019-12-24',
#                '2019-12-25', '2019-12-26', '2019-12-27', '2019-12-28',
#                '2019-12-29', '2019-12-30'],
#               dtype='datetime64[ns]', length=8034, freq='D')

# %%
test['time'] = time_date

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 8034, lat: 82, lon: 82)
# Coordinates:
#   * lat            (lat) float64 -30.12 -29.88 -29.62 ... -10.38 -10.12 -9.875
#   * lon            (lon) float64 139.9 140.1 140.4 140.6 ... 159.6 159.9 160.1
#   * time           (time) datetime64[ns] 1998-01-01 1998-01-02 ... 2019-12-30
# Data variables:
#     precipitation  (time, lat, lon) float64 ...

# %%
test.precipitation[5000,:,:].plot.contourf(levels=20, cmap='viridis')
