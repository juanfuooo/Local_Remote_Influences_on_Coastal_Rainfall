# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import netCDF4
import scipy
from scipy import stats
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import seaborn as sns

# %%
mer_tropical_box = xr.open_dataset('/Users/richard_zhang/Library/CloudStorage/OneDrive-Personal/A_Melbourne-Uni/A_Weather_for_21st_Century_RA_Internship/Local_Remote_Influences_on_Coastal_Rainfall/Data_preparation/ERA5_Tropical_Box/mer_tropical_box.nc')
sst_tropical_box = xr.open_dataset('/Users/richard_zhang/Library/CloudStorage/OneDrive-Personal/A_Melbourne-Uni/A_Weather_for_21st_Century_RA_Internship/Local_Remote_Influences_on_Coastal_Rainfall/Data_preparation/ERA5_Tropical_Box/sst_daily_tropical_band_1998_2019.nc')

# %%
mer_tropical_box = mer_tropical_box.sel(time=slice('1998-01-01', '2019-12-31'))

# %%
np_mer = mer_tropical_box['mer'].values
np_sst = sst_tropical_box['sst'].values

# %%
mer_tropical_box
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 8035, longitude: 81, latitude: 21)
# Coordinates:
#   * time       (time) datetime64[ns] 1998-01-01 1998-01-02 ... 2019-12-31
#   * longitude  (longitude) float32 150.0 150.2 150.5 150.8 ... 169.5 169.8 170.0
#   * latitude   (latitude) float32 -20.0 -19.75 -19.5 ... -15.5 -15.25 -15.0
# Data variables:
#     mer        (time, latitude, longitude) float64 -8.696e-05 ... -6.71e-05

# %%
sst_tropical_box
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 81, latitude: 21, time: 8035)
# Coordinates:
#   * longitude  (longitude) float32 150.0 150.2 150.5 150.8 ... 169.5 169.8 170.0
#   * latitude   (latitude) float32 -15.0 -15.25 -15.5 ... -19.5 -19.75 -20.0
#   * time       (time) datetime64[ns] 1998-01-01 1998-01-02 ... 2019-12-31
# Data variables:
#     sst        (time, latitude, longitude) float64 302.4 302.5 ... 299.8 299.8

# %%
np_mer = np_mer.reshape(8035*81*21)
np_sst = np_sst.reshape(8035*81*21)

# %%
plt.scatter(np_mer, np_sst, c='blue', alpha=0.5)
